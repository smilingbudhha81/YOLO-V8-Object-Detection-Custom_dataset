# %%
# !nvidia-smi
# Out:
# Sat Oct 21 13:02:23 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 10.6 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 76.2MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 11.1MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 81.0ms
# Speed: 13.5ms preprocess, 81.0ms inference, 40.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pwd
# Out:
# /content

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source='images/cat.jpg'
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images/cat.jpg: 448x640 2 cats, 214.0ms
# Speed: 3.8ms preprocess, 214.0ms inference, 9.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='images/cat.jpg'
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 77.5MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/images/cat.jpg: 448x640 1 cat, 1 couch, 195.7ms
# Speed: 3.5ms preprocess, 195.7ms inference, 9.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

#load segmentation model
model = YOLO("yolov8n-seg.pt")
model.predict(source="images/cat.jpg")
# Out:
# image 1/1 /content/images/cat.jpg: 448x640 1 cat, 1 couch, 127.0ms
# Speed: 2.9ms preprocess, 127.0ms inference, 3.3ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source='images/cat.jpg'
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 66.2MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 14.5MB/s]
# image 1/1 /content/images/cat.jpg: 224x224 Egyptian_cat 0.44, tabby 0.43, tiger_cat 0.12, lynx 0.01, tiger 0.00, 3.8ms
# Speed: 13.7ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='images/cat.jpg'
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/images/cat.jpg: 448x640 1 cat, 1 couch, 138.0ms
# Speed: 3.6ms preprocess, 138.0ms inference, 87.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
